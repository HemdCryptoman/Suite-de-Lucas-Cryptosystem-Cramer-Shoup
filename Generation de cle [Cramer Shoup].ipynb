# %%
#------------------------------------------------------------#
#Membres du groupe : El Hadji Mamadou Dia & Mohamadou Wagne
#Universite : Gaton Berger de Saint Louis
#UFR : SAT
#Parcours : Cryptotologie, Codage et Application(CCA)
#Niveau : Master I
#Module : Introduction a la Cryptographie
#Annee Universitaire : 2020/2021
#-------------------------------------------------------------#

print("________________________________________________________")
print("----------- |Cryptosysteme Cramer Shoup| ---------------")
print("________________________________________________________")
print("--------------- |Generation de cle| --------------------")
print("________________________________________________________")
def genkey(q):
    G = CyclicPermutationGroup(q)
    g1 = G.gens()
    g2 = G.gens()
    R = IntegerModRing(q)
    x1 = R.random_element()
    x2 = R.random_element()
    y1 = R.random_element()
    y2 = R.random_element()
    z = R.random_element()
    for i in range(0,len(g1)):
        k1 = g1[i]^x1
    for j in range(0,len(g2)):
        k2 = g2[j]^x2
    c = k1*k2
    for i in range(0,len(g1)):
        k3 = g1[i]^y1
    for j in range(0,len(g2)):
        k4 = g2[j]^y2
    d= k3*k4
    for i in range(0,len(g1)):
        h = g1[i]^z
    print("La cle publique est:")
    print (c , d , h)
    print("_______________________________________________________________________________________")
    print("_______________________________________________________________________________________")
    print("_______________________________________________________________________________________")
    print("La cle privee est:")
    print (x1 , x2 , y1 , y2 , z)
genkey(256)
# Out:
# ________________________________________________________
# ----------- |Cryptosysteme Cramer Shoup| ---------------
# ________________________________________________________
# --------------- |Generation de cle| --------------------
# ________________________________________________________
# La cle publique est:
# ((1,141,25,165,49,189,73,213,97,237,121,5,145,29,169,53,193,77,217,101,241,125,9,149,33,173,57,197,81,221,105,245,129,13,153,37,177,61,201,85,225,109,249,133,17,157,41,181,65,205,89,229,113,253,137,21,161,45,185,69,209,93,233,117)(2,142,26,166,50,190,74,214,98,238,122,6,146,30,170,54,194,78,218,102,242,126,10,150,34,174,58,198,82,222,106,246,130,14,154,38,178,62,202,86,226,110,250,134,18,158,42,182,66,206,90,230,114,254,138,22,162,46,186,70,210,94,234,118)(3,143,27,167,51,191,75,215,99,239,123,7,147,31,171,55,195,79,219,103,243,127,11,151,35,175,59,199,83,223,107,247,131,15,155,39,179,63,203,87,227,111,251,135,19,159,43,183,67,207,91,231,115,255,139,23,163,47,187,71,211,95,235,119)(4,144,28,168,52,192,76,216,100,240,124,8,148,32,172,56,196,80,220,104,244,128,12,152,36,176,60,200