# %%
#------------------------------------------------------------#
#Membres du groupe : El Hadji Mamadou Dia & Mohamadou Wagne
#Universite : Gaton Berger de Saint Louis
#UFR : SAT
#Parcours : Cryptotologie, Codage et Application(CCA)
#Niveau : Master I
#Module : Introduction a la Cryptographie
#Annee Universitaire : 2020/2021
#-------------------------------------------------------------#

print("________________________________________________________")
print("----------- |Cryptosysteme Cramer Shoup| ---------------")
print("________________________________________________________")
print("----------------- |Chiffrement| --------------------")
print("________________________________________________________")
def encryption(m,q):
    G = CyclicPermutationGroup(q)
    g1 = G.gens()
    g2 = G.gens()
    R = IntegerModRing(q)
    r = R.random_element()
    z = R.random_element()
    x1 = R.random_element()
    x2 = R.random_element()
    y1 = R.random_element()
    y2 = R.random_element()
    for i in range(0,len(g1)):
        u1 = g1[i]^r
    for j in range(0,len(g2)):
        u2 = g2[j]^r
    for i in range(0,len(g1)):
        e = (g1[i]^z^r)
    #print e
    a1 = str(hash(u1))
    a2 = str(hash(u2))
    a3 = str(hash(e))
    alpha = (a1,a2,a3)
    for i in range(0,len(g1)):
        k1 = g1[i]^x1
    for j in range(0,len(g2)):
        k2 = g2[j]^x2
    c = k1*k2
    for i in range(0,len(g1)):
        k3 = g1[i]^y1
    for j in range(0,len(g2)):
        k4 = g2[j]^y2
    d= k3*k4
    for i in range(0,len(alpha)):
        k = r*alpha[i]
    v = c^r*d^r
    print ("Le texte chiffre se compose de :")
    print u1,u2,e,v
encryption("Bonjour",1024)
# Out:
# ________________________________________________________
# ----------- |Cryptosysteme Cramer Shoup| ---------------
# ________________________________________________________
# ----------------- |Chiffrement| --------------------
# ________________________________________________________
# Le texte chiffre se compose de :
# (1,179,357,535,713,891,45,223,401,579,757,935,89,267,445,623,801,979,133,311,489,667,845,1023,177,355,533,711,889,43,221,399,577,755,933,87,265,443,621,799,977,131,309,487,665,843,1021,175,353,531,709,887,41,219,397,575,753,931,85,263,441,619,797,975,129,307,485,663,841,1019,173,351,529,707,885,39,217,395,573,751,929,83,261,439,617,795,973,127,305,483,661,839,1017,171,349,527,705,883,37,215,393,571,749,927,81,259,437,615,793,971,125,303,481,659,837,1015,169,347,525,703,881,35,213,391,569,747,925,79,257,435,613,791,969,123,301,479,657,835,1013,167,345,523,701,879,33,211,389,567,745,923,77,255,433,611,789,967,121,299,477,655,833,1011,165,343,521,699,877,31,209,387,565,743,921,75,253,431,609,787,965,119,297,475,653,831,1009,163,341,519,697,875,29,207,385,563,741,919,73,251,429,607,785,963,117,295,473,651,829,1007,161,339,517,695,873,27,205,383,561,739,917,71,249,427,605,783,961,115,293,471,649,827,1005,159,337,515,693,871,25,203,381,559,737,915,69,247,425,603,781,959,113,291,469,647,825,1003,157,335,513,691,869,23,201,379,557,735,913,67,245,423,601,779,957,111,289,467,645,823,1001,155,333,511,689,867,21,199,377,555,733,911,65,243,421,599,777,955,109,287,465,643,821,999,153,